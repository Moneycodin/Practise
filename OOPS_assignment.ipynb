# %%
#Problem 1: Bank Account Create a class representing a bank account with attributes like account number, account holder name, and balance. 
#Implement methods to deposit and withdraw money from the account



class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0.0):
        self.account_number=account_number
        self.account_holder_name=account_holder_name
        self.balance=balance
        
    def deposit(Self, amount):
        self.balance+=amount
        print(f"Deposited ${amount}. New balance: ${self.balance}")

    def withdraw(self, amount):
        if amount<=self.balance:
            self.balance -=amount
            print(f"Withdrawn ${amount}. New balance: ${self.balance}")
        else:
            print("Insufficient funds.")
            
    def display_account_info(self):
        print(f"Account Number: {self.account_number}")
        print(f"Account Holder Name: {self.account_holder_name}")
        print(f"Account Number: {self.balance}")

# %%
#Problem 2: Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. Implement methods to 
#calculate the yearly bonus and display employee details.


class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def calculate_yearly_bonus(self):
        # Assuming a 10% bonus for this example
        bonus_percentage = 0.10
        yearly_bonus = self.salary * bonus_percentage
        return yearly_bonus

    def display_employee_details(self):
        print("Employee ID:", self.employee_id)
        print("Name:", self.name)
        print("Salary:", self.salary)
        print("Yearly Bonus:", self.calculate_yearly_bonus())


# Example usage
if __name__ == "__main__":
    # Create an employee
    employee = Employee(employee_id=101, name="John Doe", salary=60000)
    
    # Display employee details
    employee.display_employee_details()
# Out:
# Employee ID: 101
# Name: John Doe
# Salary: 60000
# Yearly Bonus: 6000.0

# %%
#Problem 3: Vehicle Rental Create a class representing a vehicle rental system. Implement methods to rent a vehicle, return a vehicle, and display 
#available vehicles.



class Vehicle:
    def __init__(self, vehicle_id, model, available=True):
        self.vehicle_id = vehicle_id
        self.model = model
        self.available = available

    def rent_vehicle(self):
        if self.available:
            self.available = False
            print(f"Vehicle {self.vehicle_id} ({self.model}) rented successfully.")
        else:
            print(f"Vehicle {self.vehicle_id} ({self.model}) is not available for rent.")

    def return_vehicle(self):
        if not self.available:
            self.available = True
            print(f"Vehicle {self.vehicle_id} ({self.model}) returned successfully.")
        else:
            print(f"Vehicle {self.vehicle_id} ({self.model}) is already available.")

    def display_vehicle_info(self):
        availability = "available" if self.available else "not available"
        print(f"Vehicle {self.vehicle_id} ({self.model}) - {availability}")


class VehicleRentalSystem:
    def __init__(self):
        self.vehicles = {}

    def add_vehicle(self, vehicle):
        self.vehicles[vehicle.vehicle_id] = vehicle

    def rent_vehicle(self, vehicle_id):
        if vehicle_id in self.vehicles:
            self.vehicles[vehicle_id].rent_vehicle()
        else:
            print(f"Vehicle with ID {vehicle_id} not found.")

    def return_vehicle(self, vehicle_id):
        if vehicle_id in self.vehicles:
            self.vehicles[vehicle_id].return_vehicle()
        else:
            print(f"Vehicle with ID {vehicle_id} not found.")

    def display_available_vehicles(self):
        print("Available Vehicles:")
        for vehicle_id, vehicle in self.vehicles.items():
            if vehicle.available:
                vehicle.display_vehicle_info()


# Example usage
if __name__ == "__main__":
    rental_system = VehicleRentalSystem()

    # Add vehicles to the system
    vehicle1 = Vehicle(vehicle_id=1, model="Sedan")
    vehicle2 = Vehicle(vehicle_id=2, model="SUV")
    rental_system.add_vehicle(vehicle1)
    rental_system.add_vehicle(vehicle2)

    # Display available vehicles
    rental_system.display_available_vehicles()

    # Rent a vehicle
    rental_system.rent_vehicle(1)
    rental_system.display_available_vehicles()

    # Return the rented vehicle
    rental_system.return_vehicle(1)
    rental_system.display_available_vehicles()
# Out:
# Available Vehicles:
# Vehicle 1 (Sedan) - available
# Vehicle 2 (SUV) - available
# Vehicle 1 (Sedan) rented successfully.
# Available Vehicles:
# Vehicle 2 (SUV) - available
# Vehicle 1 (Sedan) returned successfully.
# Available Vehicles:
# Vehicle 1 (Sedan) - available
# Vehicle 2 (SUV) - available

# %%
#Problem 4: Library Catalog Create classes representing a library and a book. Implement methods to add books to the library, borrow books, and display 
#available books.

class Book:
    def __init__(self, title, author, available=True):
        self.title = title
        self.author = author
        self.available = available

    def borrow(self):
        if self.available:
            self.available = False
            return True
        else:
            return False

    def return_book(self):
        self.available = True


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, title, author):
        book = Book(title, author)
        self.books.append(book)

    def borrow_book(self, title):
        for book in self.books:
            if book.title == title and book.available:
                book.borrow()
                print(f"You have borrowed the book: {title}")
                return
        print(f"Book {title} is not available for borrowing.")

    def return_book(self, title):
        for book in self.books:
            if book.title == title:
                book.return_book()
                print(f"You have returned the book: {title}")
                return
        print(f"Book {title} was not found in the library.")

    def display_available_books(self):
        print("Available Books:")
        for book in self.books:
            if book.available:
                print(f"{book.title} by {book.author}")


# Example usage
if __name__ == "__main__":
    library = Library()

    # Add books to the library
    library.add_book("Book 1", "Author 1")
    library.add_book("Book 2", "Author 2")
    library.add_book("Book 3", "Author 3")

    # Display available books
    library.display_available_books()

    # Borrow a book
    library.borrow_book("Book 1")

    # Display available books after borrowing
    library.display_available_books()

    # Return the borrowed book
    library.return_book("Book 1")

    # Display available books after returning
    library.display_available_books()
# Out:
# Available Books:
# Book 1 by Author 1
# Book 2 by Author 2
# Book 3 by Author 3
# You have borrowed the book: Book 1
# Available Books:
# Book 2 by Author 2
# Book 3 by Author 3
# You have returned the book: Book 1
# Available Books:
# Book 1 by Author 1
# Book 2 by Author 2
# Book 3 by Author 3

# %%
#Problem 5: Product Inventory Create classes representing a product and an inventory system. Implement methods to add products to the inventory, 
#update product quantity, and display available products.



class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity

    def update_quantity(self, new_quantity):
        self.quantity = new_quantity


class InventorySystem:
    def __init__(self):
        self.products = {}

    def add_product(self, product_id, name, price, quantity):
        product = Product(product_id, name, price, quantity)
        self.products[product_id] = product

    def update_product_quantity(self, product_id, new_quantity):
        if product_id in self.products:
            self.products[product_id].update_quantity(new_quantity)
        else:
            print(f"Product with ID {product_id} not found.")

    def display_available_products(self):
        print("Available Products:")
        for product_id, product in self.products.items():
            print(f"Product ID: {product_id}")
            print(f"Name: {product.name}")
            print(f"Price: ${product.price:.2f}")
            print(f"Quantity: {product.quantity}")
            print()


# Example usage
if __name__ == "__main__":
    inventory_system = InventorySystem()

    # Add products to the inventory
    inventory_system.add_product(1, "Product 1", 10.0, 50)
    inventory_system.add_product(2, "Product 2", 15.0, 30)
    inventory_system.add_product(3, "Product 3", 20.0, 20)

    # Display available products
    inventory_system.display_available_products()

    # Update product quantity
    inventory_system.update_product_quantity(1, 40)

    # Display available products after updating quantity
    inventory_system.display_available_products()
# Out:
# Available Products:
# Product ID: 1
# Name: Product 1
# Price: $10.00
# Quantity: 50
#
# Product ID: 2
# Name: Product 2
# Price: $15.00
# Quantity: 30
#
# Product ID: 3
# Name: Product 3
# Price: $20.00
# Quantity: 20
#
# Available Products:
# Product ID: 1
# Name: Product 1
# Price: $10.00
# Quantity: 40
#
# Product ID: 2
# Name: Product 2
# Price: $15.00
# Quantity: 30
#
# Product ID: 3
# Name: Product 3
# Price: $20.00
# Quantity: 20

# %%
#Problem 6: Shape Calculation Create a class representing a shape with attributes like length, width, and height. Implement methods to calculate
#the area and perimeter of the shape.


class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        raise NotImplementedError("Subclasses must implement this method.")

    def calculate_perimeter(self):
        raise NotImplementedError("Subclasses must implement this method.")


class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


class Triangle(Shape):
    def calculate_area(self):
        # Using Heron's formula to calculate the area of a triangle
        s = (self.length + self.width + self.height) / 2
        return (s * (s - self.length) * (s - self.width) * (s - self.height)) ** 0.5

    def calculate_perimeter(self):
        return self.length + self.width + self.height


# Example usage
if __name__ == "__main__":
    rectangle = Rectangle(length=5, width=4)
    print("Rectangle Area:", rectangle.calculate_area())
    print("Rectangle Perimeter:", rectangle.calculate_perimeter())

    triangle = Triangle(length=3, width=4, height=5)
    print("\nTriangle Area:", triangle.calculate_area())
    print("Triangle Perimeter:", triangle.calculate_perimeter())
# Out:
# Rectangle Area: 20
# Rectangle Perimeter: 18
#
# Triangle Area: 6.0
# Triangle Perimeter: 12

# %%
#Problem 7: Student Management Create a class representing a student with attributes like student ID, name, and grades. Implement methods to calculate
#the average grade and display student details.


class Student:
    def __init__(self, student_id, name, grades=[]):
        self.student_id = student_id
        self.name = name
        self.grades = grades

    def add_grade(self, grade):
        self.grades.append(grade)

    def calculate_average_grade(self):
        if not self.grades:
            return 0.0  # Return 0 if no grades available
        total_grade = sum(self.grades)
        average_grade = total_grade / len(self.grades)
        return average_grade

    def display_student_details(self):
        print("Student ID:", self.student_id)
        print("Name:", self.name)
        print("Grades:", self.grades)
        print("Average Grade:", self.calculate_average_grade())


# Example usage
if __name__ == "__main__":
    student1 = Student(student_id=1, name="John Doe", grades=[85, 90, 78, 92])
    student1.display_student_details()

    # Add more grades and recalculate average grade
    student1.add_grade(88)
    student1.display_student_details()

    student2 = Student(student_id=2, name="Jane Smith", grades=[92, 95, 89])
    student2.display_student_details()
# Out:
# Student ID: 1
# Name: John Doe
# Grades: [85, 90, 78, 92]
# Average Grade: 86.25
# Student ID: 1
# Name: John Doe
# Grades: [85, 90, 78, 92, 88]
# Average Grade: 86.6
# Student ID: 2
# Name: Jane Smith
# Grades: [92, 95, 89]
# Average Grade: 92.0

# %%
#Problem 8: Email Management Create a class representing an email with attributes like sender, recipient, and subject. Implement methods to send an 
#email and display email details.



class Email:
    def __init__(self, sender, recipient, subject, message):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.message = message

    def send_email(self):
        # You would implement email sending logic here
        # For simplicity, we'll just display the email content
        print("Email sent successfully!")
        self.display_email_details()

    def display_email_details(self):
        print("Sender:", self.sender)
        print("Recipient:", self.recipient)
        print("Subject:", self.subject)
        print("Message:", self.message)


# Example usage
if __name__ == "__main__":
    email = Email(
        sender="sender@example.com",
        recipient="recipient@example.com",
        subject="Test Email",
        message="This is a test email message."
    )

    # Send the email and display email details
    email.send_email()
# Out:
# Email sent successfully!
# Sender: sender@example.com
# Recipient: recipient@example.com
# Subject: Test Email
# Message: This is a test email message.

# %%
#Problem 9: Social Media Profile Create a class representing a social media profile with attributes like username and posts. Implement methods to add
#posts, display posts, and search for posts by keyword.


class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, post):
        self.posts.append(post)

    def display_posts(self):
        if not self.posts:
            print("No posts available.")
        else:
            print("Posts:")
            for post in self.posts:
                print(f"- {post}")

    def search_posts(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post.lower()]
        if not matching_posts:
            print(f"No posts found matching the keyword '{keyword}'.")
        else:
            print(f"Posts matching the keyword '{keyword}':")
            for post in matching_posts:
                print(f"- {post}")


# Example usage
if __name__ == "__main__":
    profile = SocialMediaProfile(username="john_doe")

    # Add posts
    profile.add_post("Enjoying a beautiful day!")
    profile.add_post("Just had an amazing dinner.")

    # Display posts
    print("Displaying all posts:")
    profile.display_posts()

    # Search for posts by keyword
    print("\nSearching for posts with the keyword 'amazing':")
    profile.search_posts("amazing")

    print("\nSearching for posts with the keyword 'work':")
    profile.search_posts("work")
# Out:
# Displaying all posts:
# Posts:
# - Enjoying a beautiful day!
# - Just had an amazing dinner.
#
# Searching for posts with the keyword 'amazing':
# Posts matching the keyword 'amazing':
# - Just had an amazing dinner.
#
# Searching for posts with the keyword 'work':
# No posts found matching the keyword 'work'.

# %%
#Problem 10: ToDo List Create a class representing a ToDo list with attributes like tasks and due dates. Implement methods to add tasks, mark tasks
#as completed, and display pending tasks.


class ToDoList:
    def __init__(self):
        self.tasks = {}

    def add_task(self, task, due_date):
        self.tasks[task] = due_date

    def mark_task_completed(self, task):
        if task in self.tasks:
            del self.tasks[task]
            print(f"Task '{task}' marked as completed.")
        else:
            print(f"Task '{task}' not found in the ToDo list.")

    def display_pending_tasks(self):
        if not self.tasks:
            print("No pending tasks.")
        else:
            print("Pending Tasks:")
            for task, due_date in self.tasks.items():
                print(f"- {task} (Due: {due_date})")


# Example usage
if __name__ == "__main__":
    todo_list = ToDoList()

    # Add tasks
    todo_list.add_task("Complete assignment", "2023-10-20")
    todo_list.add_task("Buy groceries", "2023-10-15")
    todo_list.add_task("Call client", "2023-10-18")

    # Display pending tasks
    todo_list.display_pending_tasks()

    # Mark a task as completed
    todo_list.mark_task_completed("Buy groceries")

    # Display pending tasks after marking a task as completed
    todo_list.display_pending_tasks()
# Out:
# Pending Tasks:
# - Complete assignment (Due: 2023-10-20)
# - Buy groceries (Due: 2023-10-15)
# - Call client (Due: 2023-10-18)
# Task 'Buy groceries' marked as completed.
# Pending Tasks:
# - Complete assignment (Due: 2023-10-20)
# - Call client (Due: 2023-10-18)
